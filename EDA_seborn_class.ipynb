# %% [markdown]
# - in matplot the method is **plt.bar**
# - in the seaborn method is **countplot**
# - in matplot
# - we will take row data
# - we will create frequency table
# - we will pass the c1,c2 and dataframe name
#
# in seaborn count plot
#     -it take direct raw data
#     - we will provide columns
#     - we will provide main dataframe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv("visadataset.csv")
visa_df

# %%
colm=visa_df.columns
colm
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df["continent"].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
import os
os.getcwd()
os.makedirs('C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class notes by me\\visa_dir')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[6], line 3
#       1 import os
#       2 os.getcwd()
# ----> 3 os.makedirs('C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class notes by me\\visa_dir')
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class notes by me\\visa_dir'

# %%
for i in colm[1:]:
    dfn=visa_df[i].value_counts()
    keys=dfn.keys()
    values=dfn.values
    col=["labels","count"]
    df=pd.DataFrame(zip(keys,values),columns=col)
    path='C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class notes by me\\new_dirs'
    df.to_csv(f"{path}\\{i}_visa_df.csv",index=False)

# %%
l1=[]
for i in colm[1:]:
    path=r'C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class notes by me\\visa_dir'
    df1=pd.read_csv(f"{path}\\{i}_visa_df.csv")
    l1.append(df1)
#l1

# %%
visa_columns=os.listdir('C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class notes by me\\visa_dir')
visa_columns[1:]

# %%
#matplotlib
col=l1[1]
plt.bar("labels","count",data=col)
plt.title("Bar_chart")
plt.xlabel("class")
plt.ylabel("class_frequency")
plt.show()

# %%
for i in colm[1:]:
    dfn=visa_df[i].value_counts()
    keys=dfn.keys()
    values=dfn.values
    col=["labels","count"]
    df=pd.DataFrame(zip(keys,values),columns=col)

    plt.bar("labels","count",data=df)
    plt.title("Bar_chart")
    plt.xlabel(f"{i}class")
    plt.ylabel("class_frequency")
    plt.show()

# %%
visa_columns=os.listdir('C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class notes by me\\visa_dir')
visa_columns[1:]

# %%
#if data in save in directary the plot
for i in visa_columns[1:]:
    path=r'C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class notes by me\\visa_dir'
    df2=pd.read_csv(f"{path}\\{i}")

    plt.bar("labels","count",data=df2)
    plt.xlabel("class")
    plt.ylabel("class_frequency")
    plt.title("Bar_chart")
    plt.show()

# %%
#if data in save in directary the plot and save in directory
for i in visa_columns[1:]:
    path=r'C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class notes by me\\visa_dir'
    df2=pd.read_csv(f"{path}\\{i}")

    plt.bar("labels","count",data=df2)
    plt.xlabel("class")
    plt.ylabel("class_frequency")
    plt.title("Bar_chart")
    plt.savefig(f"{path}\\{i[:-4]}.jpg")
    plt.show()

# %% [markdown]
# - import os
# - os.getcwd()
# - os.makedirs()
# - os.path.join()

# %%
os.getcwd()

# %%
os.makedirs('C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class notes by me\\new_dirs')

# %%
root_directory=os.getcwd()
new_folder="new_dirs"
new_dir=os.path.join(root_directory,new_folder)
new_dir
# Out:
# 'C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class notes by me\\new_dirs'

# %%
for i in colm[1:]:
    cnf=visa_df[i].value_counts()
    keys=cnf.keys()
    value=cnf.values
    col=[i,"count"]
    df4=pd.DataFrame(zip(keys,values),columns=col)

    plt.bar(i,"count",data=df4)
    plt.xlabel(f"{i}class")
    plt.ylabel("class_frequency")
    plt.title("Bar Chart")
    plt.show()

# %%
root_dr=os.getcwd()
new_f1="visa_dir"
new_dirs=os.path.join(root_dr,new_f1)
new_dirs
# Out:
# 'C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class notes by me\\visa_dir'

# %%
root_dr+"\\visa_dr"

# %%
for i in visa_columns[1:]:
   # path=r'C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class notes by me\\visa_dir'
    df5=pd.read_csv(f"{new_dirs}\\{i}")

    plt.bar("labels","count",data=df5)
    plt.xlabel("class")
    plt.ylabel("class_frequency")
    plt.title("Bar_Graph")
    plt.show()

# %%
colm[1:]

# %%
continent_col=visa_df["continent"].value_counts()
country=continent_col.keys()
country

# %%
#use seaborn
plt.figure(figsize=(10,6))

sns.countplot(data=visa_df,
             x="continent",
             order=country)

# %%
new_dir    #graph
# Out:
# 'C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class notes by me\\new_dirs'

# %%
new_dirs   #dataframe
# Out:
# 'C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class notes by me\\visa_dir'

# %%
colm[1:]

# %%
l1=[]
for i in colm[1:]:
    cnf=visa_df[i].value_counts()
    keys=cnf.keys()
    l1.append(keys)
len(l1)
# Out:
# 11

# %%
#l1=[]
for i in colm[1:]:
    cnf=visa_df[i].value_counts()
    keys=cnf.keys()
    #l1.append(keys)
    
for i in colm[1:]:
    cnf=visa_df[i].value_counts()
    keys=cnf.keys()
    plt.figure(figsize=(8,5))
    sns.countplot(data=visa_df,
                 x=i,
                 order=keys)
    plt.title("Bar_Chart")
    plt.xlabel(f"{i}")
    plt.ylabel("class_frequency")
    plt.savefig(f"{sea_born}\\{i}_seaborn.jpg")
    plt.show()

# %%
os.getcwd()
os.makedirs('C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class notes by me\\sea_born')

# %%
sea_born=r'C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Class notes by me\\sea_born'

# %%
#seaborn
for i in colm[1:]:
    cnf=visa_df[i].value_counts()
    keys=cnf.keys()
  
    

for i in colm[1:]:
    plt.figure(figsize=(8,5))
    sns.countplot(data=visa_df,
                    x=i,
                    order=keys)
    plt.title("Bar_Chart")
    plt.xlabel(f"{i}")
    plt.ylabel("class_frequency")
    plt.savefig(f"{sea_born}\\{i}_seaborn.jpg")
    plt.show()

# %%
keys
# Out:
# Index(['Certified', 'Denied'], dtype='object', name='case_status')

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'open',
#  'quit']
